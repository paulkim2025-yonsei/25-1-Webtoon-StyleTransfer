# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project/JoJoGAN
# Out:
# /content/drive/.shortcut-targets-by-id/1fnIsVFyKeOK7ZA1h8U1iGJuwe6TSjZU5/project/JoJoGAN

# %%
# !ls
# Out:
# dlib_binary-20250328T160855Z-001.zip  Untitled0.ipynb  wheels-20250328T160853Z-001.zip

# %%
# !unzip /content/drive/MyDrive/project/JoJoGAN/JoJoGAN-20250328T160853Z-001.zip
# Out:
# Archive:  /content/drive/MyDrive/project/JoJoGAN/JoJoGAN-20250328T160853Z-001.zip
#    creating: JoJoGAN/.git/branches/
#    creating: JoJoGAN/.git/refs/tags/
#    creating: JoJoGAN/.git/objects/info/
#   inflating: JoJoGAN/jojogan_.py
#   inflating: JoJoGAN/util.py
#   inflating: JoJoGAN/model.py
#   inflating: JoJoGAN/predict.py
#   inflating: JoJoGAN/e4e_projection.py
#   inflating: JoJoGAN/cog.yaml
#   inflating: JoJoGAN/ninja-linux.zip
#   inflating: JoJoGAN/LICENSE
#   inflating: JoJoGAN/models/e4e_ffhq_encode.pt
#   inflating: JoJoGAN/README.md
#   inflating: JoJoGAN/inversion_codes/j_1.pt
#   inflating: JoJoGAN/inversion_codes/70_face1.pt
#   inflating: JoJoGAN/stylize.ipynb
#   inflating: JoJoGAN/teasers/sketch.gif
#   inflating: JoJoGAN/teasers/teaser.jpg
#   inflating: JoJoGAN/teasers/art.gif
#   inflating: JoJoGAN/__pycache__/util.cpython-311.pyc
#   inflating: JoJoGAN/__pycache__/e4e_projection.cpython-311.pyc
#   inflating: JoJoGAN/__pycache__/model.cpython-311.pyc
# ...
